# %%
# Cấu hình thông tin kết nối
TAILSCALE_AUTH_KEY = "tskey-auth-kkQYFRL26M11CNTRL-f8v5oJPvGk7ai93qTk4dj7xrd9DPTWXb"
HOSTNAME = "kaggle-remote-ssh"

# %%
# 1. Cài đặt các thành phần cần thiết
print("--- Đang cài đặt OpenSSH và Tailscale ---")
# !apt-get update -y && apt-get install -y openssh-server curl
# !curl -fsSL https://tailscale.com/install.sh | sh

# Khởi động dịch vụ SSH
# !mkdir -p /var/run/sshd
# !service ssh start

# %%
# 2. Chạy Tailscale và kết nối mạng ảo
import subprocess
import time

print("--- Đang khởi động Tailscaled Daemon ---")
subprocess.Popen(['tailscaled'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)

print("--- Đang thực hiện kết nối (Authentication) ---")
# --ssh: Cho phép truy cập SSH qua định danh Tailscale mà không cần password/key thủ công
# !tailscale up --authkey={TAILSCALE_AUTH_KEY} --ssh --hostname={HOSTNAME} --accept-routes

print("\n" + "="*50)
print("KẾT NỐI THÀNH CÔNG!")
print(f"Tên máy của bạn: {HOSTNAME}")
print(f"Lệnh để SSH từ máy tính của bạn: ssh root@{HOSTNAME}")
print("="*50)
